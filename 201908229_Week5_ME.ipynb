# %% [markdown]
# <a href="https://colab.research.google.com/github/Eerkz/computing_architectures-algos/blob/main/201908229_Week5_ME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ME: Benchmarking exercise for loop ordering**

# %% [markdown]
# The code below implements a simple 3-nested-loop algorithm for matrix-matrix multiplication of two n-by-n matrices, containing random float elements. Input the value of `n` below to vary the size of the input matrices.
#
# For this benchmarking exercise, the objectives are:
# *   to implement various loop ordering for matrix-matrix multiplication
# *   to observe the performance impact of loop ordering on small, medium, and large matrices
#
# Using the provided code below, please do the following:
# 1.   Fill in the indicated portions in the code below with the same 3-nested-loop MMM algorithm, but with varying loop ordering
# 2.   Decide on a at least three different values for matrix sizes (small, medium, large). Choose values in the hundreds (or larger) range for the large matrix
# 3. Run the code at least 3 times per matrix size (note that the large, and perhaps medium, matrices will take some time to run so be patient!) and record the resulting runtimes
# 4. Answer the questions below and upload your answers to the UVLe submission bin.
# 5. **BONUS** [optional] The performance will be different if the code is run on a different machine. Try running the code on your own machine (varying machines) and include your results in the analysis to answer the questions below

# %%
#!/usr/bin/env python

from time import time
from tabulate import tabulate
import random
import copy

random.seed(0)

#@title Matrix size (n-by-n)
n=10
print("size is: ", (n,n))
def init_rand(mat,n):
for x in range(n):
  new = []
  for y in range(n):
    new.append(random.random())
  mat.append(new)

def init_matrix(mat,n,value):
for x in range(n):
  new = []
  for y in range(n):
    new.append(value)
  mat.append(new)

def fill_zero(mat,n):
for x in range(n):
  for y in range(n):
    mat[x][y] = 0

A = []
B = []
C = []
print("Matrix size is %d-by-%d" % (n,n))

init_rand(A,n)
init_rand(B,n)
init_matrix(C,n,0)

ctmp = copy.deepcopy(C)

iteration = 5;

for run in range(iteration):
print("Run #: ",run)
t = time()
for i in range(n):
  for j in range(n):
    for k in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_ijk = time() - t
print("ijk completed in %f seconds" % (runtime_ijk))
print("------------------------")
### PLEASE INPUT YOUR kji CODE HERE ###
t = time()
for k in range(n):
  for i in range(n):
    for j in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_kji = time() - t
print("kji completed in %f seconds" % (runtime_kji))
print("------------------------")

### PLEASE INPUT YOUR jik CODE HERE ###
t = time()
for j in range(n):
  for i in range(n):
    for k in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_jik = time() - t
print("jik completed in %f seconds" % (runtime_jik))
print("------------------------")
### PLEASE INPUT YOUR jki CODE HERE ###
t = time()
for j in range(n):
  for k in range(n):
    for i in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_jki = time() - t
print("jki completed in %f seconds" % (runtime_jki))
print("------------------------")
### PLEASE INPUT YOUR kij CODE HERE ###
t = time()
for k in range(n):
  for i in range(n):
    for j in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_kij = time() - t
print("kij completed in %f seconds" % (runtime_kij))
print("------------------------")
fill_zero(C,n)
### PLEASE INPUT YOUR ikj CODE HERE ###
t = time()
for i in range(n):
  for k in range(n):
    for j in range(n):
      ctmp[i][j] = ctmp[i][j] + A[i][k]*B[k][j]
runtime_ikj = time() - t
print("ikj completed in %f seconds" % (runtime_ikj))
print("------------------------")
# Out:
# size is:  10
# Matrix size is 10-by-10
# Run #:  0
# ijk completed in 0.000455 seconds
# ------------------------
# kji completed in 0.000449 seconds
# ------------------------
# jik completed in 0.000492 seconds
# ------------------------
# jki completed in 0.000467 seconds
# ------------------------
# kij completed in 0.000440 seconds
# ------------------------
# ikj completed in 0.000457 seconds
# ------------------------
# Run #:  1
# ijk completed in 0.000469 seconds
# ------------------------
# kji completed in 0.000468 seconds
# ------------------------
# jik completed in 0.000477 seconds
# ------------------------
# jki completed in 0.000468 seconds
# ------------------------
# kij completed in 0.000454 seconds
# ------------------------
# ikj completed in 0.000437 seconds
# ------------------------
# Run #:  2
# ijk completed in 0.000469 seconds
# ------------------------
# kji completed in 0.000469 seconds
# ------------------------
# jik completed in 0.000473 seconds
# ------------------------
# jki completed in 0.000483 seconds
# ------------------------
# kij completed in 0.000458 seconds
# ------------------------
# ikj completed in 0.000437 seconds
# ------------------------
# Run #:  3
# ijk completed in 0.000463 seconds
# ------------------------
# kji completed in 0.000451 seconds
# ------------------------
# jik completed in 0.000477 seconds
# ------------------------
# jki completed in 0.000492 seconds
# ------------------------
# kij completed in 0.000461 seconds
# ------------------------
# ikj completed in 0.000564 seconds
# ------------------------
# Run #:  4
# ijk completed in 0.000510 seconds
# ------------------------
# kji completed in 0.000464 seconds
# ------------------------
# jik completed in 0.000526 seconds
# ------------------------
# jki completed in 0.000500 seconds
# ------------------------
# kij completed in 0.000469 seconds
# ------------------------
# ikj completed in 0.000472 seconds
# ------------------------
# size is:  100
# Matrix size is 100-by-100
# Run #:  0
# ijk completed in 0.454159 seconds
# ------------------------
# kji completed in 0.446887 seconds
# ------------------------
# jik completed in 0.447710 seconds
# ------------------------
# jki completed in 0.463701 seconds
# ------------------------
# kij completed in 0.433244 seconds
# ------------------------
# ikj completed in 0.427999 seconds
# ------------------------
# Run #:  1
# ijk completed in 0.460545 seconds
# ------------------------
# kji completed in 0.434859 seconds
# ------------------------
# jik completed in 0.451222 seconds
# ------------------------
# jki completed in 0.447390 seconds
# ------------------------
# kij completed in 0.414084 seconds
# ------------------------
# ikj completed in 0.424959 seconds
# ------------------------
# Run #:  2
# ijk completed in 0.459996 seconds
# ------------------------
# kji completed in 0.443466 seconds
# ------------------------
# jik completed in 0.447386 seconds
# ------------------------
# jki completed in 0.459132 seconds
# ------------------------
# kij completed in 0.422416 seconds
# ------------------------
# ikj completed in 0.416673 seconds
# ------------------------
# Run #:  3
# ijk completed in 0.460408 seconds
# ------------------------
# kji completed in 0.436067 seconds
# ------------------------
# jik completed in 0.450658 seconds
# ------------------------
# jki completed in 0.450328 seconds
# ------------------------
# kij completed in 0.429971 seconds
# ------------------------
# ikj completed in 0.445421 seconds
# ------------------------
# Run #:  4
# ijk completed in 0.464360 seconds
# ------------------------
# kji completed in 0.435071 seconds
# ------------------------
# jik completed in 0.447634 seconds
# ------------------------
# jki completed in 0.461254 seconds
# ------------------------
# kij completed in 0.425479 seconds
# ------------------------
# ikj completed in 0.429813 seconds
# ------------------------
# size is:  500
# Matrix size is 500-by-500
# Run #:  0
# ijk completed in 65.075092 seconds
# ------------------------
# kji completed in 56.231957 seconds
# ------------------------
# jik completed in 58.330690 seconds
# ------------------------
# jki completed in 71.153216 seconds
# ------------------------
# kij completed in 55.585817 seconds
# ------------------------
# ikj completed in 54.672804 seconds
# ------------------------
# Run #:  1
# ijk completed in 64.493159 seconds
# ------------------------
# kji completed in 56.897272 seconds
# ------------------------
# jik completed in 58.354018 seconds
# ------------------------
# jki completed in 70.943035 seconds
# ------------------------
# kij completed in 56.612099 seconds
# ------------------------
# ikj completed in 54.946378 seconds
# ------------------------
# Run #:  2
# ijk completed in 65.643533 seconds
# ------------------------
# kji completed in 58.499258 seconds
# ------------------------
# jik completed in 59.201662 seconds
# ------------------------
# jki completed in 71.844789 seconds
# ------------------------
# kij completed in 56.396090 seconds
# ------------------------
# ikj completed in 55.147542 seconds
# ------------------------
# Run #:  3
# ijk completed in 64.472388 seconds
# ------------------------
# kji completed in 57.484097 seconds
# ------------------------
# jik completed in 58.348059 seconds
# ------------------------
# jki completed in 69.071099 seconds
# ------------------------
# kij completed in 56.925558 seconds
# ------------------------
# ikj completed in 55.109574 seconds
# ------------------------
# Run #:  4
# ijk completed in 63.731483 seconds
# ------------------------
# kji completed in 57.389278 seconds
# ------------------------
# jik completed in 58.160815 seconds
# ------------------------
# jki completed in 69.807631 seconds
# ------------------------
# kij completed in 56.940544 seconds
# ------------------------
# ikj completed in 54.693037 seconds
# ------------------------

# %% [markdown]
# # ME Questions
# 1. What matrix sizes did you choose?
# 2. How many times did you run the code per matrix size?
# 3. List the runtimes you recorded per matrix size (you can organize your results into a table)
# 4. What are the average runtimes per matrix size
# 5. What can you say about how the runtime is affected by matrix size? What do you think are the reasons behind slowness due to matrix size?
# 6. Are there any loop orderings that consistently run slower than the others?
# 7. Is the slow performance observable for all the matrix sizes?
# What do you think are the reasons behind the slower performance with changing loop ordering?
# 8. **BONUS** Google Colab provides virtualizes resources for you to run code on Google's machines. Read up a bit on how Google Colab runs your code and describe how you think the architecture of Colab affects the performance of the code
